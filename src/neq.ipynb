# %%
using DataFrames
using Gadfly
using Compose
set_default_plot_size(30cm, 12cm)

# %%
# Energies
home = "/home/german/labo/17/pdz/"

# Temperature
tlb_1 = readdlm("$home/run/lb/neq/data/corta_4/temp");
df_tlb_1 = DataFrame(Temperature=tlb_1[:, 2], NSTEP=tlb_1[:, 1]);

# %%
plot(df_tlb_1, Geom.line, x="NSTEP", y="Temperature",
Guide.title("NEQ run 10ps"),
Theme(minor_label_font_size = 10pt, major_label_font_size = 15pt,
key_title_font_size=20pt, key_label_font_size=20pt))
# Out:
# Plot(...)
